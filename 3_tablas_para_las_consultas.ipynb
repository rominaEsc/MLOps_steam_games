# %% [markdown]
# # Librerías y configuraciones

# %%
import pandas as pd
import ast
import json

# %%
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ---

# %% [markdown]
# # Carga de datos

# %%
df_genres = pd.read_csv('data/df_genres.csv')
df_item_genre = pd.read_csv('data/df_item_genre.csv')
df_items = pd.read_csv('data/df_items.csv')
df_reviews = pd.read_csv('data/df_reviews.csv')
df_users_items = pd.read_csv('data/df_users_items.csv')
df_users = pd.read_csv('data/df_users.csv')

# %% [markdown]
# ----

# %% [markdown]
# Funciones auxiliares

# %%
def items_faltantes(columna_principal,columna_relacionada):
    list_elementos_unicos_de_columna_principal = list(columna_principal.unique())
    list_elementos_unicos_de_columna_relacionada = list(columna_relacionada.unique())
    print(len(list_elementos_unicos_de_columna_principal))
    print(len(list_elementos_unicos_de_columna_relacionada))

    # Convertir las listas a conjuntos
    list_elementos_unicos_de_columna_principal = set(list_elementos_unicos_de_columna_principal)
    list_elementos_unicos_de_columna_relacionada = set(list_elementos_unicos_de_columna_relacionada)

    # Encontrar los elementos que están en set_items_en_df_item_genre pero no en set_items_en_df_items
    elementos_no_en_df_items =   list_elementos_unicos_de_columna_relacionada - list_elementos_unicos_de_columna_principal
    # Obtener la cantidad y los elementos que no están en df_items
    cantidad_elementos_no_en_df_items = len(elementos_no_en_df_items)
    lista_elementos_no_en_df_items = list(elementos_no_en_df_items)

    print("Cantidad de items de la columna relacionada que no se encuentran en la columna principal ", (cantidad_elementos_no_en_df_items))
    print("Elementos que faltan en la columna principal:", lista_elementos_no_en_df_items)
    return lista_elementos_no_en_df_items

# %% [markdown]
# ----

# %% [markdown]
# Las tablas:
# - df_genres
# - df_item_genre
# - df_items
# - df_reviews
# - df_users_items
# - df_users
#
# estan relacionadas por lo que no deberíamos tener:
# - df_items
#     - items en df_item_genre que no esten en df_items
#     - items en df_users_items que no esten en df_items
#     - items en df_reviews que no esten en  df_items
# - df_users
#     - users en reviews que no esten en users
#     - users en users_items que no esten en users

# %% [markdown]
#     - items en df_item_genre que no esten en df_items

# %%
items_de_df_item_genre_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_item_genre.item_id)
# Out:
# 30754
# 27621
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
#     - items en df_users_items que no esten en df_items

# %%
items_de_df_users_items_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_users_items.item_id)
# Out:
# 30754
# 8234
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
#     - items en df_reviews que no esten en  df_items

# %%
items_de_df_reviews_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_reviews.item_id)
# Out:
# 30754
# 3488
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal
 347630, 413170, 222710, 253430, 255480, 349700, 359940, 255500, 321040, 228880, 407060, 34330, 230940, 374300, 374301, 255520, 249380, 355880, 265770, 34350, 226880, 441920, 331330, 433730, 323140, 228940, 364110, 38480, 220760, 282201, 253530, 22110, 396900, 212580, 71270, 323180, 319090, 239220, 394870, 243320, 349830, 323210, 9870, 306830, 351890, 42650, 319130, 200350, 226980, 319150, 251570, 222900, 417460, 317110, 42680, 439995, 272060, 18110, 403150, 407250, 341720, 394970, 251610, 71390, 282350, 202485, 323320, 337660, 337661, 388870, 358150, 231180, 36620, 378641, 378642, 378645, 36630, 251670, 378648, 378649, 333600, 210720, 233250, 407330, 61220, 1840, 239410, 214850, 317250, 421700, 235340, 231250, 239450, 2701 ...

# %% [markdown]
# crearemos una lista de estos items

# %%
items_sobrantes = set(items_de_df_item_genre_que_no_estan_en_df_items + items_de_df_users_items_que_no_estan_en_df_items +items_de_df_reviews_que_no_estan_en_df_items)

# %%
len(items_sobrantes)
# Out:
# 551

# %%
df_items[df_items.item_id==245760]
# Out:
# Empty DataFrame
# Columns: [item_id, title, url, release_date, developer, price]
# Index: []

# %% [markdown]
# Existen 2867 items que se encuentran en las tablas relacionadas pero no en la tabla sonde se almacena la info de items.
# Para que la información sea consistente eliminaremos estos items de los df.

# %% [markdown]
# Eliminamos los items .... de df_item_genre

# %%
df_item_genre[df_item_genre.item_id.isin(items_sobrantes)]
# Out:
# Empty DataFrame
# Columns: [item_id, genres]
# Index: []

# %%
df_item_genre = df_item_genre[~(df_item_genre.item_id.isin(items_sobrantes))]

# %% [markdown]
# Eliminamos los items .... de df_users_item

# %%
df_users_items[df_users_items.item_id.isin(items_sobrantes)]
# Out:
# Empty DataFrame
# Columns: [user_id, item_id, playtime_forever]
# Index: []

# %%
df_users_items = df_users_items[~(df_users_items.item_id.isin(items_sobrantes))]

# %% [markdown]
# Eliminamos los items .... de df_reviews

# %%
df_reviews[df_reviews.item_id.isin(items_sobrantes)]
# Out:
#                  user_id                             funny  \
# 2      76561197970982479                               NaN
# 3                js41637                               NaN
# 23     76561198089393905  5 people found this review funny
# 42     76561198043472122                               NaN
# 67     76561198054540475                               NaN
# ...                  ...                               ...
# 52169  76561198222628548  9 people found this review funny
# 52188            wayfeng  1 person found this review funny
# 52209  76561198267374962  1 person found this review funny
# 52210  76561198270958927                               NaN
# 52225  76561198296402247                               NaN
#
#                           posted last_edited  item_id  \
# 2         Posted April 21, 2011.         NaN    43110
# 3          Posted June 24, 2014.         NaN   251610
# 23      Posted February 1, 2015.         NaN    72850
# 42     Posted December 19, 2014.         NaN    33440
# 67     Posted February 13, 2015.         NaN    12210
# ...                          ...         ...      ...
# 52169     Posted April 10, 2015.         NaN   359800
# 52188             Posted May 22.         NaN   369200
# 52209  Posted December 29, 2015.         NaN   369200
# 52210             Posted July 3.         NaN   381210
# 52225           Posted April 24.         NaN   280790
#
#                                                helpful  recommend  \
# 2                                       No ratings yet       True
# 3      15 of 20 people (75%) found this review helpful       True
# 23      3 of 3 people (100%) found this review helpful       True
# 42       1 of 3 people (33%) found this review helpful      False
# 67                                      No ratings yet       True
# ...                                                ...        ...
# 52169  29 of 52 people (56%) found this review helpful       True
# 52188    1 of 3 people (33%) found this review helpful       True
# 52209    1 of 2 people (50%) found this review helpful       True
# 52210     0 of 2 people (0%) found this review helpful       True
# 52225    2 of 3 people (67%) found this review helpful       True
#
#                                                                                                     review  \
# 2      Great atmosphere. The gunplay can be a bit chunky at times but at the end of the day this game i...
# 3      I know what you think when you see this title "Barbie Dreamhouse Party" but do not be intimidate...
# 23     Killed the Emperor, nobody cared and got away with it. Accidentally killed a chicken and everybo...
# 42                                                                                  This Game Doesn't Work
# 67     This game Is great.Its charmingits imersiveits funAnd it works every time for me. I have no idea...
# ...                                                                                                    ...
# 52169  Okay, You may take this game as "'S***"' But no this game is like a simulator but free in this a...
# 52188  MOTOKO MOTOKO MOTOKO MOTOKO MOTOKO MOTOKO MOTOKO <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3...
# 52209        Why I voted yes? 1. Girl characters have boobs.2. Anime(+10 skill)3. More enjoyable than Cod.
# 52210  Fix your ♥♥♥♥ing game, de rank me for no reason. 20 back to 19, i go away for 20 mins i come bac...
# 52225                      Great game, specially if you need to past time or are bored, game to escape on!
#
#       posted_date
# 2      2011-04-21
# 3      2014-06-24
# 23     2015-02-01
# 42     2014-12-19
# 67     2015-02-13
# ...           ...
# 52169  2015-04-10
# 52188         NaN
# 52209  2015-12-29
# 52210         NaN
# 52225         NaN
#
# [5262 rows x 9 columns]

# %%
df_reviews = df_reviews[~(df_reviews.item_id.isin(items_sobrantes))]

# %% [markdown]
#     - users en reviews que no esten en users

# %%
items_de_df_reviews_que_no_estan_en_df_users = items_faltantes(df_users.user_id,df_reviews.user_id)
# Out:
# 70912
# 21584
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
#     - users en users_items que no esten en users

# %%
items_de_df_users_items_que_no_estan_en_df_users = items_faltantes(df_users.user_id,df_users_items.user_id)
# Out:
# 70912
# 33131
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
# Podemos ver que no existen usuarios en df_reviews y df_users_items que no se encuentren en df_users

# %% [markdown]
# Las tablas:
# - df_genres
# - df_item_genre
# - df_items
# - df_reviews
# - df_users_items
# - df_users

# %%
df_genres.to_csv("data/df_genres.csv",index=False)
df_item_genre.to_csv("data/df_item_genre.csv",index=False)
df_users_items.to_csv("data/df_users_items.csv",index=False)
df_reviews.to_csv("data/df_reviews.csv",index=False)
df_users_items.to_csv("data/df_users_items.csv",index=False)

# %% [markdown]
# ----

# %% [markdown]
# # Tabla df_user_id_item_id_price

# %%
df_user_id_item_id_price = df_users_items[['user_id','item_id']].merge(df_items[['item_id','price']], on = 'item_id', how='left')
df_user_id_item_id_price
# Out:
#                    user_id  item_id  price
# 0        76561197970982479       10   9.99
# 1        76561197970982479       30   4.99
# 2        76561197970982479      300   9.99
# 3        76561197970982479      240  19.99
# 4        76561197970982479     3830   9.99
# ...                    ...      ...    ...
# 1899976  76561198055329422   107410  39.99
# 1899977  76561198055329422   273110   0.00
# 1899978  76561198055329422   433850  19.99
# 1899979  76561198055329422   304930   0.00
# 1899980  76561198055329422   227940   0.00
#
# [1899981 rows x 3 columns]

# %%
df_user_id_item_id_price.to_csv("data/df_user_id_item_id_price.csv",index=False)

# %% [markdown]
# ----

# %% [markdown]
# # Tabla Developer

# %%
df_items.head(2)
# Out:
#    item_id                title  \
# 0   761140  Lost Summoner Kitty
# 1   643980            Ironbound
#
#                                                              url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_Summoner_Kitty/   2018-01-04
# 1            http://store.steampowered.com/app/643980/Ironbound/   2018-01-04
#
#           developer  price
# 0         Kotoshiro   4.99
# 1  Secret Level SRL   0.00

# %%
df_items.isna().sum()
# Out:
# item_id            0
# title           1932
# url                0
# release_date    1936
# developer       3154
# price              0
# dtype: int64

# %%
df_items.columns
# Out:
# Index(['item_id', 'title', 'url', 'release_date', 'developer', 'price'], dtype='object')

# %%
len(df_items.developer.unique())
# Out:
# 10632

# %%
df_developer = df_items[['developer','price','release_date']]
df_developer
# Out:
#                       developer  price release_date
# 0                     Kotoshiro   4.99   2018-01-04
# 1              Secret Level SRL   0.00   2018-01-04
# 2                  Poolians.com   0.00   2017-07-24
# 3                          彼岸领域   0.99   2017-12-07
# 4                           NaN   2.99          NaN
# ...                         ...    ...          ...
# 30749        Nikita "Ghost_RUS"   1.99   2018-01-04
# 30750                    Sacada   4.99   2018-01-04
# 30751  Laush Dmitriy Sergeevich   1.99   2018-01-04
# 30752             xropi,stev3ns   4.99   2017-09-02
# 30753                       NaN   4.99          NaN
#
# [30754 rows x 3 columns]

# %%
df_developer.isna().sum()
# Out:
# developer       1222
# price              0
# release_date       0
# dtype: int64

# %%
#Eliminaremos los valores nulos en release_date
df_developer.dropna(subset='release_date',inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6052\3174557118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_developer.dropna(subset='release_date',inplace=True)

# %%
df_developer.isna().sum()

# %%
lista_release = ((df_developer.release_date.unique()))

# %%
len(lista_release)
# Out:
# 3446

# %%
sorted(lista_release,reverse=True)
# Out:
# ['coming soon',
#  'Sep 2014',
#  'Sep 2009',
#  'SOON™',
#  'SOON',
#  'Oct 2016',
#  'Oct 2010',
#  'Oct 2009',
#  'Nov 2016',
#  'Nov 2014',
#  'May 2015',
#  'May 2014',
#  'Mar 2010',
#  'Jun 2016',
#  'Jun 2015',
#  'Jun 2009',
#  'Jul 2017',
#  'Jul 2016',
#  'Jul 2014',
#  'Jul 2010',
#  'Jan 2017',
#  'Jan 2015',
#  'Jan 2010',
#  'Feb 2015',
#  'Feb 2013',
#  'Feb 2011',
#  'Dec 2012',
#  'Aug 2015',
#  'Aug 2014',
#  'Apr 2017',
#  'Apr 2016',
#  '2016-12-02',
#  '2016-12-01',
#  '2016-11-30',
#  '2016-11-29',
#  '2016-11-28',
#  '2016-11-25',
#  '2016-11-24',
#  '2016-11-23',
#  '2016-11-22',
#  '2016-11-21',
#  '2016-11-20',
#  '2016-11-19',
#  '2016-11-18',
#  '2016-11-17',
#  '2016-11-16',
#  '2016-11-15',
#  '2016-11-14',
#  '2016-11-13',
#  '2016-11-12',
#  '2016-11-11',
#  '2016-11-10',
#  '2016-11-09',
#  '2016-11-08',
#  '2016-11-07',
#  '2016-11-06',
#  '2016-11-05',
#  '2016-11-04',
#  '2016-11-03',
#  '2016-11-02',
#  '2016-11-01',
#  '2016-10-31',
#  '2016-10-30',
#  '2016-10-29',
#  '2016-10-28',
#  '2016-10-27',
#  '2016-10-26',
#  '2016-10-25',
#  '2016-10-24',
#  '2016-10-23',
#  '2016-10-22',
#  '2016-10-21',
#  '2016-10-20',
#  '2016-10-19',
#  '2016-10-18',
#  '2016-10-17',
#  '2016-10-16',
#  '2016-10-15',
#  '2016-10-14',
#  '2016-10-13',
#  '2016-10-12',
#  '2016-10-11',
#  '2016-10-10',
#  '2016-10-08',
#  '2016-10-07',
#  '2016-10-06',
#  '2016-10-05',
#  '2016-10-04',
#  '2016-10-03',
#  '2016-10-02',
#  '2016-10-01',
#  '2016-09-30',
#  '2016-09-29',
#  '2016-09-28',
#  '2016-09-27',
#  '2016-09-26',
#  '2016-09-25',
#  '2016-09-24',
#  '2016-09-23',
#  '2016-09-22',
#  '2016-09-21',
#  '2016-09-20',
#  '2016-09-19',
#  '2016-09-17',
#  '2016-09-16',
#  '2016-09-15',
#  '2016-09-14',
#  '2016-09-13',
#  '2016-09-12',
#  '2016-09-11',
#  '2016-09-10',
#  '2016-09-09',
#  '2016-09-08',
#  '2016-09-07',
#  '2016-09-06',
#  '2016-09-05',
#  '2016-09-04',
#  '2016-09-03',
#  '2016-09-02',
#  '2016-09-01',
#  '2016-08-31',
#  '2016-08-30',
#  '2016-08-29',
#  '2016-08-28',
#  '2016-08-27',
#  '2016-08-26',
#  '2016-08-25',
#  '2016-08-24',
#  '2016-08-23',
#  '2016-08-22',
#  '2016-08-21',
#  '2016-08-20',
#  '2016-08-19',
#  '2016-08-18',
#  '2016-08-17',
#  '2016-08-16',
#  '2016-08-15',
#  '2016-08-14',
#  '2016-08-13',
#  '2016-08-12',
#  '2016-08-11',
#  '2016-08-10',
#  '2016-08-09',
#  '2016-08-08',
#  '2016-08-07',
#  '2016-08-06',
#  '2016-08-05',
#  '2016-08-04',
#  '2016-08-03',
#  '2016-08-02',
#  '2016-08-01',
#  '2016-07-31',
#  '2016-07-30',
#  '2016-07-29',
#  '2016-07-28',
#  '2016-07-27',
#  '2016-07-26',
#  '2016-07-25',
#  '2016-07-24',
#  '2016-07-22',
#  '2016-07-21',
#  '2016-07-20',
#  '2016-07-19',
#  '2016-07-18',
#  '2016-07-17',
#  '2016-07-16',
#  '2016-07-15',
#  '2016-07-14',
#  '2016-07-13',
#  '2016-07-12',
#  '2016-07-11',
#  '2016-07-10',
#  '2016-07-09',
#  '2016-07-08',
#  '2016-07-07',
#  '2016-07-06',
#  '2016-07-05',
#  '2016-07-04',
#  '2016-07-02',
#  '2016-07-01',
#  '2016-06-30',
#  '2016-06-29',
#  '2016-06-28',
#  '2016-06-27',
#  '2016-06-26',
#  '2016-06-25',
#  '2016-06-24',
#  '2016-06-23',
#  '2016-06-22',
#  '2016-06-21',
#  '2016-06-20',
#  '2016-06-19',
#  '2016-06-18',
#  '2016-06-17',
#  '2016-06-16',
#  '2016-06-15',
#  '2016-06-14',
#  '2016-06-13',
#  '2016-06-12',
#  '2016-06-11',
#  '2016-06-10',
#  '2016-06-09',
#  '2016-06-08',
#  '2016-06-07',
#  '2016-06-06',
#  '2016-06-05',
#  '2016-06-04',
#  '2016-06-03',
#  '2016-06-02',
#  '2016-06-01',
#  '2016-05-31',
#  '2016-05-30',
#  '2016-05-29',
#  '2016-05-28',
#  '2016-05-27',
#  '2016-05-26',
#  '2016-05-25',
#  '2016-05-24',
#  '2016-05-23',
#  '2016-05-22',
#  '2016-05-21',
#  '2016-05-20',
#  '2016-05-19',
#  '2016-05-18',
#  '2016-05-17',
#  '2016-05-16',
#  '2016-05-14',
#  '2016-05-13',
#  '2016-05-12',
#  '2016-05-11',
#  '2016-05-10',
#  '2016-05-09',
#  '2016-05-07',
#  '2016-05-06',
#  '2016-05-05',
#  '2016-05-04',
#  '2016-05-03',
#  '2016-05-02',
#  '2016-05-01',
#  '2016-04-30',
#  '2016-04-29',
#  '2016-04-28',
#  '2016-04-27',
#  '2016-04-26',
#  '2016-04-25',
#  '2016-04-24',
#  '2016-04-23',
#  '2016-04-22',
#  '2016-04-21',
#  '2016-04-20',
#  '2016-04-19',
#  '2016-04-18',
#  '2016-04-17',
#  '2016-04-16',
#  '2016-04-15',
#  '2016-04-14',
#  '2016-04-13',
#  '2016-04-12',
#  '2016-04-11',
#  '2016-04-10',
#  '2016-04-09',
#  '2016-04-08',
#  '2016-04-07',
#  '2016-04-06',
#  '2016-04-05',
#  '2016-04-04',
#  '2016-04-03',
#  '2016-04-02',
#  '2016-04-01',
#  '2016-03-31',
#  '2016-03-30',
#  '2016-03-29',
#  '2016-03-28',
#  '2016-03-27',
#  '2016-03-25',
#  '2016-03-24',
#  '2016-03-23',
#  '2016-03-22',
#  '2016-03-21',
#  '2016-03-20',
#  '2016-03-19',
#  '2016-03-18',
#  '2016-03-17',
#  '2016-03-16',
#  '2016-03-15',
#  '2016-03-14',
#  '2016-03-13',
#  '2016-03-12',
#  '2016-03-11',
#  '2016-03-10',
#  '2016-03-09',
#  '2016-03-08',
#  '2016-03-07',
#  '2016-03-06',
#  '2016-03-04',
#  '2016-03-03',
#  '2016-03-02',
#  '2016-03-01',
#  '2016-02-29',
#  '2016-02-28',
#  '2016-02-27',
#  '2016-02-26',
#  '2016-02-25',
#  '2016-02-24',
#  '2016-02-23',
#  '2016-02-22',
#  '2016-02-20',
#  '2016-02-19',
#  '2016-02-18',
#  '2016-02-17',
#  '2016-02-16',
#  '2016-02-15',
#  '2016-02-12',
#  '2016-02-11',
#  '2016-02-10',
#  '2016-02-09',
#  '2016-02-08',
#  '2016-02-07',
#  '2016-02-05',
#  '2016-02-04',
#  '2016-02-03',
#  '2016-02-02',
#  '2016-02-01',
#  '2016-01-31',
#  '2016-01-29',
#  '2016-01-28',
#  '2016-01-27',
#  '2016-01-26',
#  '2016-01-25',
#  '2016-01-23',
#  '2016-01-22',
#  '2016-01-21',
#  '2016-01-20',
#  '2016-01-19',
#  '2016-01-18',
#  '2016-01-15',
#  '2016-01-14',
#  '2016-01-13',
#  '2016-01-12',
#  '2016-01-11',
#  '2016-01-09',
#  '2016-01-08',
#  '2016-01-07',
#  '2016-01-06',
#  '2016-01-05',
#  '2016-01-04',
#  '2016-01-03',
#  '2016-01-02',
#  '2016-01-01',
#  '2015-12-31',
#  '2015-12-30',
#  '2015-12-29',
#  '2015-12-28',
#  '2015-12-25',
#  '2015-12-24',
#  '2015-12-23',
#  '2015-12-22',
#  '2015-12-21',
#  '2015-12-18',
#  '2015-12-17',
#  '2015-12-16',
#  '2015-12-15',
#  '2015-12-14',
#  '2015-12-11',
#  '2015-12-10',
#  '2015-12-09',
#  '2015-12-08',
#  '2015-12-07',
#  '2015-12-05',
#  '2015-12-04',
#  '2015-12-03',
#  '2015-12-02',
#  '2015-12-01',
#  '2015-11-30',
#  '2015-11-29',
#  '2015-11-28',
#  '2015-11-27',
#  '2015-11-26',
#  '2015-11-25',
#  '2015-11-24',
#  '2015-11-23',
#  '2015-11-22',
#  '2015-11-20',
#  '2015-11-19',
#  '2015-11-18',
#  '2015-11-17',
#  '2015-11-16',
#  '2015-11-15',
#  '2015-11-14',
#  '2015-11-13',
#  '2015-11-12',
#  '2015-11-11',
#  '2015-11-10',
#  '2015-11-09',
#  '2015-11-06',
#  '2015-11-05',
#  '2015-11-04',
#  '2015-11-03',
#  '2015-11-02',
#  '2015-11-01',
#  '2015-10-31',
#  '2015-10-30',
#  '2015-10-29',
#  '2015-10-28',
#  '2015-10-27',
#  '2015-10-26',
#  '2015-10-24',
#  '2015-10-23',
#  '2015-10-22',
#  '2015-10-21',
#  '2015-10-20',
#  '2015-10-19',
#  '2015-10-18',
#  '2015-10-16',
#  '2015-10-15',
#  '2015-10-14',
#  '2015-10-13',
#  '2015-10-12',
#  '2015-10-09',
#  '2015-10-08',
#  '2015-10-07',
#  '2015-10-06',
#  '2015-10-05',
#  '2015-10-04',
#  '2015-10-02',
#  '2015-10-01',
#  '2015-09-30',
#  '2015-09-29',
#  '2015-09-28',
#  '2015-09-27',
#  '2015-09-25',
#  '2015-09-24',
#  '2015-09-23',
#  '2015-09-22',
#  '2015-09-21',
#  '2015-09-20',
#  '2015-09-19',
#  '2015-09-18',
#  '2015-04-07',
#  '2015-04-06',
#  '2015-04-03',
#  '2015-04-02',
#  '2015-04-01',
#  '2015-03-31',
#  '2015-03-30',
#  '2015-03-27',
#  '2015-03-26',
#  '2015-03-25',
#  '2015-03-24',
#  '2015-03-23',
#  '2015-03-20',
#  '2015-03-19',
#  '2015-03-18',
#  '2015-03-17',
#  '2015-03-16',
#  '2015-03-15',
#  ...]

# %% [markdown]
# Tenemos filas que contienen strings como 'coming soon', 'SOON™','SOON', que eliminaremos, ya que indican que el item aun no se encuentra disponible.
# Y fechas con formato mes, año (ej:'Oct 2016') y Año, mes, Dia (ej: '2015-03-18')
# Crearemos una columna año en la cual extraeremos solo los años de estas fechas.

# %%
df_developer[df_developer.release_date.isin(['coming soon','SOON™','SOON'])]
# Out:
#                   developer  price release_date
# 12496  Onlyjoy`s production   0.99         SOON
# 30611              CI Games  19.99  coming soon
# 30651       David Szymanski  20.00        SOON™

# %%
df_developer.shape
# Out:
# (28818, 3)

# %%
df_developer = df_developer[~df_developer.release_date.isin(['coming soon','SOON™','SOON'])]

# %%
df_developer.shape
# Out:
# (28815, 3)

# %%
# Convierte la columna 'release_date' al formato de fecha
df_developer['release_date'] = pd.to_datetime(df_developer['release_date'], errors='coerce')

# Extrae el año de la columna 'release_date'
df_developer['year'] = df_developer['release_date'].dt.year
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6052\841622376.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_developer['release_date'] = pd.to_datetime(df_developer['release_date'], errors='coerce')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6052\841622376.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_developer['year'] = df_developer['release_date'].dt.year

# %%
df_developer[df_developer.release_date == 'Oct 2016']
# Out:
#                developer  price release_date  year
# 6906           TTCX Inc.   0.00   2016-10-01  2016
# 20336  Tall Tail Studios  19.99   2016-10-01  2016

# %%
df_developer = df_developer[['developer', 'price','year']]

# %%
df_developer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28815 entries, 0 to 30752
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   developer  27593 non-null  object
#  1   price      28815 non-null  float64
#  2   year       28815 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 900.5+ KB

# %%
df_developer.isna().sum()
# Out:
# developer    1222
# price           0
# year            0
# dtype: int64

# %%
df_developer.dropna(subset='developer',inplace=True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6052\78096362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_developer.dropna(subset='developer',inplace=True)

# %%
df_developer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27593 entries, 0 to 30752
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   developer  27593 non-null  object
#  1   price      27593 non-null  float64
#  2   year       27593 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 862.3+ KB

# %%
df_developer
# Out:
#                       developer  price  year
# 0                     Kotoshiro   4.99  2018
# 1              Secret Level SRL   0.00  2018
# 2                  Poolians.com   0.00  2017
# 3                          彼岸领域   0.99  2017
# 5           Trickjump Games Ltd   3.99  2018
# ...                         ...    ...   ...
# 30748           Bidoniera Games   1.99  2018
# 30749        Nikita "Ghost_RUS"   1.99  2018
# 30750                    Sacada   4.99  2018
# 30751  Laush Dmitriy Sergeevich   1.99  2018
# 30752             xropi,stev3ns   4.99  2017
#
# [27593 rows x 3 columns]

# %%
df_developer.developer = df_developer.developer.str.lower()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_6052\1169576898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_developer.developer = df_developer.developer.str.lower()

# %%
df_developer.to_csv('data/df_developer.csv',index= False)
