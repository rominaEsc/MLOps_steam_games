# %% [markdown]
# # Librerías y configuraciones

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ---

# %% [markdown]
# # Carga de datos

# %%
df_genres = pd.read_csv('data/df_genres.csv')
df_item_genre = pd.read_csv('data/df_item_genre.csv')
df_items = pd.read_csv('data/df_items.csv')
df_reviews = pd.read_csv('data/df_reviews.csv')
df_users_items = pd.read_csv('data/df_users_items.csv')
df_users = pd.read_csv('data/df_users.csv')

# %% [markdown]
# ----

# %% [markdown]
# Funciones auxiliares

# %%
def items_faltantes(columna_principal,columna_relacionada):
    list_elementos_unicos_de_columna_principal = list(columna_principal.unique())
    list_elementos_unicos_de_columna_relacionada = list(columna_relacionada.unique())
    print(len(list_elementos_unicos_de_columna_principal))
    print(len(list_elementos_unicos_de_columna_relacionada))

    # Convertir las listas a conjuntos
    list_elementos_unicos_de_columna_principal = set(list_elementos_unicos_de_columna_principal)
    list_elementos_unicos_de_columna_relacionada = set(list_elementos_unicos_de_columna_relacionada)

    # Encontrar los elementos que están en set_items_en_df_item_genre pero no en set_items_en_df_items
    elementos_no_en_df_items =   list_elementos_unicos_de_columna_relacionada - list_elementos_unicos_de_columna_principal
    # Obtener la cantidad y los elementos que no están en df_items
    cantidad_elementos_no_en_df_items = len(elementos_no_en_df_items)
    lista_elementos_no_en_df_items = list(elementos_no_en_df_items)

    print("Cantidad de items de la columna relacionada que no se encuentran en la columna principal ", (cantidad_elementos_no_en_df_items))
    print("Elementos que faltan en la columna principal:", lista_elementos_no_en_df_items)
    return lista_elementos_no_en_df_items

# %% [markdown]
# ----

# %% [markdown]
# Las tablas:
# - df_genres
# - df_item_genre
# - df_items
# - df_reviews
# - df_users_items
# - df_users
#
# estan relacionadas por lo que no deberíamos tener:
# - df_items
#     - items en df_item_genre que no esten en df_items
#     - items en df_users_items que no esten en df_items
#     - items en df_reviews que no esten en  df_items
# - df_users
#     - users en reviews que no esten en users
#     - users en users_items que no esten en users

# %% [markdown]
#     - items en df_item_genre que no esten en df_items

# %%
items_de_df_item_genre_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_item_genre.item_id)
# Out:
# 30754
# 28851
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  1230
# Elementos que faltan en la columna principal: [696350, 204840, 393270, 344140, 573520, 344150, 630870, 401500, 598110, 335970, 450660, 721000, 598120, 335981, 360560, 98421, 426110, 319620, 688274, 303250, 303251, 712870, 295100, 377020, 327870, 262341, 418000, 237780, 704740, 336100, 737510, 622820, 368870, 491760, 401650, 737530, 762120, 516360, 393500, 295210, 254260, 418110, 205120, 340, 319830, 434520, 426340, 754020, 369010, 311670, 328060, 737660, 278910, 598410, 672140, 467340, 344470, 459160, 393630, 410030, 901553, 328120, 344510, 696770, 770510, 352720, 377300, 369130, 369131, 672240, 737780, 737790, 393730, 713220, 98821, 303630, 606740, 320030, 729640, 508460, 664120, 426560, 246340, 295500, 688730, 303710, 754270, 295530, 688750, 361070, 598640, 443000, 746110, 402050, 574090, 680590, 311950, 426650, 459460, 377540, 525010, 525019, 508650, 353020, 271110, 385820, 328480, 320290, 754470, 680750, 582460, 549700, 328530, 344920, 328560, 246640, 303990, 99200, 476041, 476050, 426900, 345000, 377770, 394190, 590810, 345050, 738270, 590820, 402410, 517100, 705530, 771070, 664580, 500740, 418840, 353320, 369710, 410680, 369720, 386110, 427090, 599140, 615530, 394350, 459890, 328821, 459900, 574590, 337050, 681120, 214190, 410800, 42180, 402630, 443590, 320710, 640200, 566490, 640230, 419060, 34050, 312590, 386320, 58643, 255252, 738580, 58645, 58646, 730390, 58648, 468250, 492820, 492821, 492822, 714020, 533800, 410920, 492840, 353590, 410940, 329020, 689470, 247120, 320860, 320880, 755070, 755071, 755072, 755073, 386430, 34180, 304520, 419210, 411020, 738710, 738711, 337310, 386470, 304570, 468410, 394710, 91609, 419290, 394720, 91616, 550370, 304610, 337380, 386530, 321010, 394740, 509430, 321020, 730630, 730631, 730632, 378380, 697870, 337430, 394790, 329260, 304690, 329270, 362040, 362050, 730700, 362070, 329310, 312930, 706150, 427630, 50820, 329350, 714380, 632470, 329370, 689820, 526000, 526001, 526002, 378550, 378551, 657080, 378552, 272060, 698050, 313030, 427720, 747220, 386780, 771810, 337640, 337660, 337661, 403210, 485130, 681740, 411410, 329500, 321310, 296750, 337710, 1840, 444210, 362300, 730940, 395070, 378690, 304970, 370520, 591710, 386910, 386911, 386913, 370530, 386920, 575340, 542612, 51100, 337830, 501680, 387000, 411580, 313290, 313320, 501740, 428030, 321540, 387080, 706580, 690200, 313372, 616490, 444460, 632880, 428090, 387140, 215120, 567380, 772180, 297050, 772190, 34910, 321630, 329823, 346220, 673910, 755830, 288900, 362630, 673930, 379030, 321690, 379040, 772260, 346290, 747700, 436410, 723130, 362710, 313560, 633060, 690410, 35050, 510190, 395510, 731390, 346370, 502020, 10520, 256280, 452890, 305440, 305450, 608580, 420170, 338250, 772430, 354650, 305510, 379250, 231801, 371070, 379270, 321930, 698770, 264610, 510370, 371140, 321990, 436680, 281050, 231910, 502250, 518660, 2570, 494090, 322060, 346640, 666140, 666150, 420390, 731690, 420410, 338490, 526910, 313920, 346690, 248410, 445020, 764510, 346720, 338540, 264841, 494240, 371370, 682670, 420540, 395970, 420560, 756450, 379620, 412390, 273130, 379630, 674550, 355070, 740100, 11020, 330511, 437010, 723750, 207660, 527150, 404280, 363320, 387910, 543560, 658270, 658271, 494430, 658280, 658304, 658305, 658306, 347010, 617350, 445320, 445321, 445330, 715670, 338840, 396190, 756640, 658340, 297896, 297897, 297898, 314280, 396240, 363480, 355290, 642010, 355300, 551913, 551914, 551915, 732140, 347120, 297970, 355320, 445440, 773120, 396290, 445450, 314390, 298010, 650270, 642080, 379970, 650310, 715850, 470090, 625740, 371800, 715870, 404580, 584820, 257140, 715900, 224380, 724100, 265350, 380050, 617620, 396440, 527520, 396450, 339120, 60600, 298180, 396490, 363740, 355550, 306401, 380130, 617720, 363770, 396540, 388350, 568580, 363780, 363781, 216330, 617740, 404760, 363810, 601380, 298300, 535880, 413000, 413001, 437580, 355660, 675170, 372070, 707950, 454000, 322940, 716170, 339360, 404910, 413110, 413120, 576960, 740800, 650690, 372 ...

# %% [markdown]
#     - items en df_users_items que no esten en df_items

# %%
items_de_df_users_items_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_users_items.item_id)
# Out:
# 30754
# 10050
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  1677
# Elementos que faltan en la columna principal: [40960, 245760, 262150, 475150, 221200, 352280, 24600, 360480, 352290, 221220, 204840, 24620, 254000, 24630, 57400, 335930, 344130, 254020, 335950, 24660, 254040, 100, 41070, 368750, 344180, 221300, 417910, 213120, 516230, 393360, 458900, 368790, 221340, 8350, 360610, 8360, 385200, 221360, 8370, 254130, 24760, 8380, 352450, 295110, 98510, 418000, 286930, 336100, 24820, 221430, 49400, 41210, 524540, 24830, 368900, 319750, 24850, 24860, 377120, 360760, 16700, 418110, 442700, 57680, 340, 319830, 434520, 16730, 385370, 352610, 295270, 418150, 409960, 409970, 221560, 459130, 409980, 328060, 205180, 278910, 49540, 409990, 311700, 459160, 65950, 90530, 434600, 360880, 467380, 8640, 205250, 33220, 328140, 352720, 508380, 33250, 33260, 319980, 270830, 377330, 246260, 360950, 33270, 238070, 107000, 319990, 33280, 320000, 270850, 467460, 246280, 393740, 205330, 238110, 49700, 205350, 311850, 369200, 238130, 426560, 213570, 33350, 467530, 508490, 328270, 98900, 238170, 516700, 303710, 221790, 358330, 303720, 467560, 57970, 483960, 17020, 246400, 508550, 500360, 303760, 33440, 344750, 508590, 90800, 254650, 492220, 443080, 303820, 492240, 33500, 33510, 303850, 320240, 459510, 336630, 33530, 426750, 41730, 33540, 402180, 385800, 205590, 230170, 33580, 320300, 320310, 344900, 377670, 246600, 377680, 475990, 385880, 377690, 361320, 435060, 99200, 295810, 107400, 312200, 517000, 336790, 107430, 361400, 271290, 17340, 58300, 410560, 287680, 50120, 492490, 33740, 230350, 369620, 33750, 426970, 205790, 410590, 33780, 17400, 295930, 238590, 484350, 254980, 492560, 508950, 377880, 58400, 255010, 402470, 402471, 402472, 402473, 402474, 402475, 402476, 402477, 402478, 402479, 402480, 402481, 402482, 402483, 402484, 402485, 402486, 402487, 402488, 402489, 402490, 402491, 402492, 402493, 402494, 402495, 386110, 312390, 500810, 410700, 320590, 107600, 312410, 263260, 468060, 205930, 492660, 246900, 33910, 238710, 9340, 50310, 418950, 304270, 58510, 402591, 402592, 402593, 402594, 402595, 402596, 402597, 402598, 402599, 361640, 402600, 402601, 402602, 402603, 402604, 214190, 402605, 42160, 402606, 402607, 402608, 58540, 91310, 451760, 9400, 17600, 214210, 402630, 34000, 214230, 50400, 361710, 25840, 361720, 214270, 361730, 25860, 378120, 361740, 25870, 263440, 386320, 361750, 1309, 361760, 1313, 279840, 222500, 214310, 361770, 304430, 214320, 361780, 329020, 378180, 525640, 247120, 378020, 238960, 411000, 320890, 230780, 107900, 460160, 34180, 17800, 17810, 353690, 34220, 345520, 370100, 50640, 50650, 370140, 99810, 394740, 99830, 222710, 255480, 9740, 255500, 288270, 321040, 345620, 321070, 34330, 312860, 255520, 411181, 411182, 411183, 411184, 411185, 99890, 468530, 411186, 411187, 411190, 411188, 411191, 411192, 411189, 411194, 411193, 108100, 99920, 362070, 321110, 394840, 271970, 222820, 214640, 50800, 239220, 394870, 312960, 9860, 501380, 50820, 34440, 9870, 42640, 34450, 42650, 34460, 263840, 296610, 42660, 485040, 18100, 222900, 42680, 403130, 272060, 18110, 419520, 42690, 362180, 362190, 50900, 42710, 370390, 362200, 394970, 362210, 403170, 42730, 362220, 386800, 50930, 362230, 321270, 304890, 362240, 9990, 50950, 362250, 231180, 10000, 362260, 444180, 362270, 321310, 345890, 50980, 50990, 239410, 321330, 51000, 288570, 362300, 214850, 42830, 34650, 239450, 460640, 10080, 51040, 272230, 34670, 460660, 42870, 280440, 296830, 493440, 1920, 427920, 509840, 206740, 51100, 10170, 501690, 468930, 10190, 501720, 255960, 247770, 272350, 501740, 296950, 321540, 428040, 403470, 18450, 215060, 247830, 18460, 501800, 452650, 34860, 444460, 280620, 100410, 18490, 297020, 264260, 460870, 419910, 436300, 215120, 2130, 297060, 43110, 272490, 264300, 346220, 247930, 436350, 305280, 297090, 206980, 313480, 444560, 43160, 313500, 346270, 223390, 10400, 264360, 452780, 346290, 10430, 35010, 354510, 207060, 35030, 280790, 485590, 354520, 329950, 354530, 354540, 10480, 231670, 354550, 420090, 362750, 346370, 223490, 42011 ...

# %% [markdown]
#     - items en df_reviews que no esten en  df_items

# %%
items_de_df_reviews_que_no_estan_en_df_items = items_faltantes(df_items.item_id,df_reviews.item_id)
# Out:
# 30754
# 3488
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  551
# Elementos que faltan en la columna principal: [245760, 315392, 262150, 475150, 290830, 274450, 247830, 313372, 307230, 360480, 221220, 241700, 333860, 501800, 452650, 96300, 210990, 41010, 266290, 57400, 297020, 34880, 403520, 251970, 315460, 366660, 55370, 344140, 24660, 274520, 39000, 34910, 450660, 43110, 383080, 211050, 41070, 258160, 221300, 282740, 417910, 331900, 213120, 233610, 444560, 96400, 293010, 43160, 313500, 223390, 233630, 243870, 264360, 266410, 452780, 221360, 385200, 254130, 200900, 295110, 422100, 280790, 334040, 418010, 438490, 243930, 399580, 329950, 336100, 368870, 235760, 401650, 221430, 231670, 49400, 315640, 366844, 366845, 223490, 346370, 368900, 420110, 381210, 24860, 446750, 356640, 276770, 35110, 397610, 254260, 397620, 360760, 260410, 321860, 57680, 340, 92500, 317780, 270680, 373080, 16730, 385370, 323930, 256350, 358750, 227680, 295270, 430440, 20840, 207210, 342380, 227700, 373110, 328060, 278910, 268670, 313730, 49540, 233860, 291210, 344460, 313740, 223630, 354702, 410, 256410, 375200, 264610, 338340, 102820, 301480, 414130, 336310, 223670, 444860, 209340, 4540, 375230, 33220, 4550, 213450, 12750, 342480, 219600, 281050, 322010, 338400, 330210, 383460, 231910, 315880, 340460, 473580, 377330, 256500, 31220, 360950, 238070, 33280, 422400, 270850, 12800, 246280, 72200, 2570, 317960, 322060, 234000, 322070, 264730, 203290, 33310, 268830, 354850, 205350, 338470, 31270, 281130, 404011, 404012, 404013, 369200, 401980, 340540, 229950, 334400, 324170, 201290, 326220, 23120, 39510, 266840, 238170, 248410, 219740, 221790, 338540, 496240, 299640, 17020, 463490, 309890, 258700, 363150, 424590, 338580, 219800, 33440, 70310, 246440, 412332, 344750, 508590, 314030, 21170, 31410, 299700, 293560, 254650, 240320, 2760, 322250, 303820, 395980, 4830, 219870, 264930, 250600, 371440, 340730, 240380, 402180, 340740, 385800, 211720, 408330, 11020, 314130, 379670, 320300, 15150, 224060, 351040, 334660, 234310, 240460, 377680, 297810, 13140, 299860, 475990, 109400, 109410, 265061, 246640, 299890, 435060, 250740, 267130, 359290, 15230, 295810, 220050, 242590, 11170, 373680, 416690, 203701, 105400, 271290, 240570, 322490, 209873, 203730, 330710, 105430, 363480, 410590, 236510, 437220, 201700, 469990, 273390, 332790, 250870, 265210, 316410, 328700, 238590, 445440, 414730, 447500, 226320, 207890, 384020, 384021, 347160, 224280, 357400, 234530, 203810, 48180, 410680, 257080, 269370, 224320, 203850, 320590, 269390, 107600, 56400, 334930, 281690, 201830, 205930, 48240, 244850, 246900, 267380, 267381, 9340, 509060, 294020, 275590, 269450, 304270, 201870, 72850, 375960, 490650, 11420, 289950, 208030, 224420, 361640, 332970, 58540, 91310, 214190, 42160, 339120, 289970, 224440, 216250, 292030, 298180, 91333, 402630, 218310, 13510, 15560, 228560, 212180, 214230, 218330, 19680, 212220, 431360, 441600, 378120, 449800, 263440, 44310, 496920, 267550, 44320, 343330, 3370, 302380, 304430, 214320, 259380, 259381, 13640, 314700, 447820, 247120, 370002, 218450, 269650, 38240, 218470, 232810, 202090, 238960, 359800, 107900, 228740, 447880, 245130, 226700, 349580, 3470, 28050, 212370, 353690, 269730, 388520, 277930, 345520, 265650, 370100, 468410, 277950, 261570, 245190, 21970, 50650, 357850, 99810, 21995, 243180, 325100, 347630, 413170, 222710, 253430, 255480, 349700, 359940, 255500, 321040, 228880, 407060, 34330, 230940, 374300, 374301, 255520, 249380, 355880, 265770, 34350, 226880, 441920, 331330, 433730, 323140, 228940, 364110, 38480, 220760, 282201, 253530, 22110, 396900, 212580, 71270, 323180, 319090, 239220, 394870, 243320, 349830, 323210, 9870, 306830, 351890, 42650, 319130, 200350, 226980, 319150, 251570, 222900, 417460, 317110, 42680, 439995, 272060, 18110, 403150, 407250, 341720, 394970, 251610, 71390, 282350, 202485, 323320, 337660, 337661, 388870, 358150, 231180, 36620, 378641, 378642, 378645, 36630, 251670, 378648, 378649, 333600, 210720, 233250, 407330, 61220, 1840, 239410, 214850, 317250, 421700, 235340, 231250, 239450, 2701 ...

# %% [markdown]
# crearemos una lista de estos items

# %%
items_sobrantes = set(items_de_df_item_genre_que_no_estan_en_df_items + items_de_df_users_items_que_no_estan_en_df_items +items_de_df_reviews_que_no_estan_en_df_items)

# %%
len(items_sobrantes)
# Out:
# 2867

# %%
df_items[df_items.item_id==245760]
# Out:
# Empty DataFrame
# Columns: [item_id, title, url, release_date, developer, price]
# Index: []

# %% [markdown]
# Existen 2867 items que se encuentran en las tablas relacionadas pero no en la tabla donde se almacena la info de items.
# Para que la información sea consistente eliminaremos estos items de los df.

# %% [markdown]
# Eliminamos items de df_item_genre

# %%
df_item_genre[df_item_genre.item_id.isin(items_sobrantes)]
# Out:
#        item_id      genres
# 32      768800      Casual
# 33      768800       Indie
# 34      768800      Racing
# 35      768800  Simulation
# 36      768570      Action
# ...        ...         ...
# 71528   771810      Action
# 71529   771810   Adventure
# 71530   771810       Indie
# 71535   769330      Casual
# 71536   769330       Indie
#
# [3199 rows x 2 columns]

# %%
df_item_genre = df_item_genre[~(df_item_genre.item_id.isin(items_sobrantes))]

# %% [markdown]
# Eliminamos items de df_users_item

# %%
df_users_items[df_users_items.item_id.isin(items_sobrantes)]
# Out:
#                    user_id  item_id  playtime_forever
# 12       76561197970982479      340                37
# 16       76561197970982479     9340               692
# 31       76561197970982479    23120                53
# 34       76561197970982479    35010               570
# 40       76561197970982479    24860               437
# ...                    ...      ...               ...
# 3246314  76561198312638244   202990                21
# 3246315  76561198312638244   212910               490
# 3246337  76561198320038728    39000                71
# 3246342  76561198320136420   496920                 2
# 3246351  76561198329548331   519140                 3
#
# [449797 rows x 3 columns]

# %%
df_users_items = df_users_items[~(df_users_items.item_id.isin(items_sobrantes))]

# %% [markdown]
# Eliminamos items de df_reviews

# %%
df_reviews[df_reviews.item_id.isin(items_sobrantes)]
# Out:
#                  user_id  item_id  recommend posted_date  year  \
# 2      76561197970982479    43110       True  2011-04-21  2011
# 3                js41637   251610       True  2014-06-24  2014
# 23     76561198089393905    72850       True  2015-02-01  2015
# 42     76561198043472122    33440      False  2014-12-19  2014
# 67     76561198054540475    12210       True  2015-02-13  2015
# ...                  ...      ...        ...         ...   ...
# 52169  76561198222628548   359800       True  2015-04-10  2015
# 52188            wayfeng   369200       True         NaN     0
# 52209  76561198267374962   369200       True  2015-12-29  2015
# 52210  76561198270958927   381210       True         NaN     0
# 52225  76561198296402247   280790       True         NaN     0
#
#        sentiment_analysis
# 2                       2
# 3                       2
# 23                      0
# 42                      0
# 67                      2
# ...                   ...
# 52169                   0
# 52188                   2
# 52209                   2
# 52210                   0
# 52225                   0
#
# [5262 rows x 6 columns]

# %%
df_reviews = df_reviews[~(df_reviews.item_id.isin(items_sobrantes))]

# %% [markdown]
#     - users en reviews que no esten en users

# %%
items_de_df_reviews_que_no_estan_en_df_users = items_faltantes(df_users.user_id,df_reviews.user_id)
# Out:
# 70912
# 21584
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
#     - users en users_items que no esten en users

# %%
items_de_df_users_items_que_no_estan_en_df_users = items_faltantes(df_users.user_id,df_users_items.user_id)
# Out:
# 70912
# 67829
# Cantidad de items de la columna relacionada que no se encuentran en la columna principal  0
# Elementos que faltan en la columna principal: []

# %% [markdown]
# Podemos ver que no existen usuarios en df_reviews y df_users_items que no se encuentren en df_users

# %% [markdown]
# Las tablas:
# - df_genres
# - df_item_genre
# - df_items
# - df_reviews
# - df_users_items
# - df_users

# %%
df_genres.to_csv("data/df_genres.csv",index=False)
df_item_genre.to_csv("data/df_item_genre.csv",index=False)
df_users_items.to_csv("data/df_users_items.csv",index=False)
df_reviews.to_csv("data/df_reviews.csv",index=False)
df_users_items.to_csv("data/df_users_items.csv",index=False)
